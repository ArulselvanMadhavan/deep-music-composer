# %% [markdown]
# ## Music visualizations
#
# 1. To run the code in this section you have to install Musescore
#    and set your config file(~/.music21rc) as shown below
#    ```xml
#    <preference name="musescoreDirectPNGPath" value="/Applications/MuseScore 2.app/Contents/MacOS/mscore" />
#    ```

# %%
# Generate Chord Visualization
from music21 import *

# %%
cstream = converter.parse("data/trainData/chords/003.mid")
cstream.show()

# %%
mstream = converter.parse("data/trainData/melody/003.mid")
mstream.show()

# %%
graph.plotStream(cstream)

# %%
graph.plotStream(mstream)
